# %%
# %matplotlib inline
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import yaml

# %%
def summarize_candidate(c):
    return c['name'] + " : " + str(c['votes']) + " votes, était " + ('éligible' if c['electable'] else 'non éligible') + " et " + ('votable' if c['votable'] else 'non votable')

def plot_results_pie(archive):
    results = archive['candidates']
    candidates = [c for c in results if c['votable']]

    labels = [c['name'] + " (" + str(c['votes']) + ")" for c in candidates]
    sizes = [c['votes'] for c in candidates]
    colors = [c['color'] for c in candidates]

    explode = [0.1] + [0] * (len(candidates) - 1)

    figs, axs = plt.subplots(1, 2)

    figs.set_size_inches(13, 3)
    axs[0].pie(sizes, explode=explode, colors=colors, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
    axs[0].axis('equal')

    axs[1].axis("off")

    clust_data = [(summarize_candidate(c), ) for c in results]
    axs[1].table(cellText=clust_data,loc='center',edges='open')

    plt.show()

def display_year_intro(archive):
    display(HTML('<h2>Edition ' +  str(archive['year']) + ', vainqueur: ' + archive['winner'] + '</h2>'))

def display_year_summary(archive):
    display_year_intro(archive)
    plot_results_pie(archive)

# %%
file = open('../data/halloffame.yml')
halloffame = yaml.load(file, Loader=yaml.FullLoader)
archives = halloffame['archives']

# %%
display_year_summary(archives[2026])
# Out:
# <h2>Edition 2026, vainqueur: Azur</h2>

# %%
display_year_summary(archives[2025])
# Out:
# <h2>Edition 2025, vainqueur: Mystik</h2>

# %%
display_year_summary(archives[2024])
# Out:
# <h2>Edition 2024, vainqueur: Atlas</h2>

# %%
display_year_summary(archives[2023])
# Out:
# <h2>Edition 2023, vainqueur: Peppers</h2>

# %%
display_year_summary(archives[2022])
# Out:
# <h2>Edition 2022, vainqueur: Sparrow</h2>

# %%
display_year_summary(archives[2021])
# Out:
# <h2>Edition 2021, vainqueur: Xanthos</h2>

# %%
display_year_summary(archives[2020])
# Out:
# <h2>Edition 2020, vainqueur: Nova</h2>

# %%
display_year_summary(archives[2019])
# Out:
# <h2>Edition 2019, vainqueur: DJANGO</h2>

# %%
display_year_summary(archives[2018])
# Out:
# <h2>Edition 2018, vainqueur: FUEGO</h2>

# %%
display_year_summary(archives[2017])
# Out:
# <h2>Edition 2017, vainqueur: Macao</h2>

# %%
display_year_summary(archives[2016])
# Out:
# <h2>Edition 2016, vainqueur: Lagoon</h2>

# %%
display_year_summary(archives[2015])
# Out:
# <h2>Edition 2015, vainqueur: ZEPHYR</h2>

# %%
display_year_summary(archives[2014])
# Out:
# <h2>Edition 2014, vainqueur: Ferus</h2>

# %%
display_year_summary(archives[2013])
# Out:
# <h2>Edition 2013, vainqueur: Huguette</h2>

# %%
display_year_summary(archives[2012])
# Out:
# <h2>Edition 2012, vainqueur: Osmoz</h2>

# %%
display_year_summary(archives[2011])
# Out:
# <h2>Edition 2011, vainqueur: Illégal</h2>

# %%
display_year_summary(archives[2010])
# Out:
# <h2>Edition 2010, vainqueur: ExtaZ</h2>

# %%
display_year_summary(archives[2009])
# Out:
# <h2>Edition 2009, vainqueur: Epik</h2>

# %%
display_year_summary(archives[2008])
# Out:
# <h2>Edition 2008, vainqueur: PUTCH</h2>

# %%
display_year_summary(archives[2007])
# Out:
# <h2>Edition 2007, vainqueur: ESIEENCE</h2>

# %%
display_year_summary(archives[2006])
# Out:
# <h2>Edition 2006, vainqueur: Atiz</h2>
